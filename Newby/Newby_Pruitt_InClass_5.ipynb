# %% [markdown]
# # In Class Exercise 5: Systems of Linear Equations

# %% [markdown]
# Robin: Driver -- Jason: Navigator

# %% [markdown]
# 1- Write the Force equations using matrix equation of the form $$ F = \hat{K}x - b$$
# $$
# F_1 = −k_1(x_1 − L_1) + k_2(x_2 − x_1 −L_2)\\
# F_2 = −k_2(x_2 − x_1 − L_2) + k_3(x_3 − x_2 −L_3)\\
# F_3 = −k_3(x_3 − x_2 − L_3) + k_4(L_w − x_3 −L_4)\\
# $$
# Solving on paper, we get the following for $\hat{K}$ and $b$:
#
# $$
# \hat{K}=
# \begin{bmatrix}
# -(k_1+k_2) & k_2 & 0\\
# k_2 & -(k_2+k_3) & k_3\\
# 0 & k_3 & -(k_3 + k_4)
# \end{bmatrix}
# \mbox{ and }
# b =
# -\begin{bmatrix}
# k_1L_1 - k_2L_2 \\
# k_2L_2 - k_3L_3 \\
# k_3L_3 +k_4L_W-k_4L_4
# \end{bmatrix}
# $$

# %% [markdown]
# 2- Write a program to solve for the rest positions of the masses in equilibrium and the final lengths of the springs

# %%
import numpy as np
import matplotlib.pyplot as plt

def ksolver(k, l, l_w):
    """ksolver takes in
    k - a vector of size 4, with each index the spring constant of each spring in the system
    l - a vector of size 4, with each index the unstretched length of each spring
    l_w - the distance of the entire system from wall to wall"""
    
    # Matrix that maps the spring constants to the x vector in K*x = b eqn
    bigK = np.array([
        [-(k[0] + k[1]), k[1], 0],
        [k[1], -(k[1] + k[2]), k[2]],
        [0, k[2], -(k[2] + k[3])]
    ])

    # matrix b of constants for K*x = b eqn
    b = -np.array([
         k[0] * l[0] - k[1] * l[1],
         k[1] * l[1] - k[2] * l[2],
         k[2] * l[2] + k[3] * l_w - k[3] * l[3]
    ])

    # take the inverse of the matrix K to solve for x
    invk = np.linalg.inv(bigK)
    
    # the x vector of positions
    xs = invk @ b

    springlengths = np.array([xs[0], xs[1]-xs[0], xs[2]-xs[1], l_w-xs[2]])

    return xs, springlengths

# %% [markdown]
# 3-Try your program with the following values, and for each case include a brief statement in your write-up using general physical arguments to explain the results

# %%
k_a = np.array([1, 2, 3, 4])
k_b = k_a.copy() # copy for supposed runtime performance
k_c = np.array([1, 1, 1, 1])
k_d = np.array([1, 1, 1, 0])
k_e = np.array([0, 1, 1, 0])

L_a = k_c.copy()
L_b = L_a.copy()
L_c = np.array([2, 2, 1, 1])
L_d = L_c.copy()
L_e = L_c.copy()

L_w_a = 4
L_w_b = 10
L_w_c = L_w_a
L_w_d = L_w_a
L_w_e = L_w_a

xA, lengthsA = ksolver(k_a, L_a, L_w_a)
xB, lengthsB = ksolver(k_b, L_b, L_w_b)
xC, lengthsC = ksolver(k_c, L_c, L_w_c)
xD, lengthsD = ksolver(k_d, L_d, L_w_d)
# xE, lengthsE = ksolver(k_e, L_e, L_w_e)

print(f'a) Mass positions - {xA}, spring lengths - {lengthsA} ')
print(f'b) Mass positions - {xB}, spring lengths - {lengthsB} ')
print(f'c) Mass positions - {xC}, spring lengths - {lengthsC} ') 
print(f'd) Mass positions - {xD}, spring lengths - {lengthsD} ') # note that these answers are physically unreasonable
# print(f'e) Mass positions - {xE}, spring lengths - {lengthsE} ') -- part e will not work because the matrix is singular
# Out:
# a) Mass positions - [1. 2. 3.], spring lengths - [1. 1. 1. 1.]
# b) Mass positions - [3.88 6.32 8.28], spring lengths - [3.88 2.44 1.96 1.72]
# c) Mass positions - [1.5 3.  3.5], spring lengths - [1.5 1.5 0.5 0.5]
# d) Mass positions - [2. 4. 5.], spring lengths - [ 2.  2.  1. -1.]

# %% [markdown]
# a) It is reasonable that the springs all end with length 1 even though they have different spring constants because their equilibrium lengths are all 1. This means that none of them are under any sort of compression or tension, so they are all relaxed at their ideal lengths.
# b)This time, the springs have the same equilibrium lengths of 1 each, but their tensions affect the positions of the weights as they are forced to be stretched to bridge a gap of length 10. As a result, we see the springs with the lowest constants extend the most as they are the most flexible.
# c)This time the spring constants are the same, but hte springs have different equilibrium lengths, so while the springs settle at different lengths, they all settle at the same amount of displacement from their equilibrium, 0.5 away from their ideal length each in this case.
# d)The spring lengths here are not physically reasonable as the model does not take into account the boundary wall on the right. Since hte spring connecting to that wall is given zero spring constant, it does not force any conditions on the positions of the masses or lengths of the springs, so all the other springs ignore the wall entirely and extend to their equilibrium lengths. This causes the spring length for the k=0 spring to be computed to be negative, as it gets flipped in orientation as the masses move past through the rightmost wall.
# e) We can't really talk about the physical arguments for case d as the matrix appears to be singular, or at least very ill-conditioned.

# %% [markdown]
# 4-Challenge Question:
# The force on the right-hand wall is $F_{rw} = −k_4(L_w − x_3 − L_4).$
# 4a) Have your program solve $\hat{K}x = b$, evaluate $F_{rw}$, and plot it as a function of $L_w$.
# For the other parameters, select any nontrivial (i.e. not zero) values. Since the matrix $\hat{K}$ is fixed, it is more efficient to use matrix inverse rather than Gaussian elimination.
#
# 4b) Verify numerically that the force on the right wall is $F_{rw} = −k_0(L_w −L_0)$ where
# $$ L_0 = L_1 + L_2 + L_3 + L_4$$
# and $$\frac{1}{k_0}=
# \frac{1}{k_1}
# +
# \frac{1}{k_2}
# +
# \frac{1}{k_3}
# +
# \frac{1}{k_4}
# .$$
# This is the law of equivalent springs.

# %%
def ksolverF(k, l, l_w):
    """ksolver takes in
    k - a vector of size 4, with each index the spring constant of each spring in the system
    l - a vector of size 4, with each index the unstretched length of each spring
    l_w - the distance of the entire system from wall to wall"""
    
    # Matrix that maps the spring constants to the x vector in K*x = b eqn
    bigK = np.array([
        [-(k[0] + k[1]), k[1], 0],
        [k[1], -(k[1] + k[2]), k[2]],
        [0, k[2], -(k[2]+k[3])]
    ])

    # matrix b of constants for K*x = b eqn
    b = -np.array([
         k[0] * l[0] - k[1] * l[1],
         k[1] * l[1] - k[2] * l[2],
         k[2] * l[2] + k[3] * l_w - k[3] * l[3]
    ])

    invk = np.linalg.inv(bigK)
    xs = invk @ b

    springlengths = np.array([xs[0], xs[1] - xs[0], xs[2] - xs[1], l_w - xs[2]])
    
    # Expression of Force on the right wall from problem 
    F_rw = -k[3] * (l_w - xs[2] - l[3])
    
    # quantities used to verify Law of Equivalent springs
    L_0 = np.sum(l)
    k_0 = 1/(1/k[0] + 1/k[1] + 1/k[2] + 1/k[3])

    # Expresssion of Law of Equivalent springs
    F_equiv = -k_0 * (l_w - L_0)

    return F_rw, F_equiv

# want a function of L_{w}
lwsArray = np.arange(1, 10, 0.2)
Fs = np.empty(lwsArray.shape)
Fq = np.empty(lwsArray.shape)

for i, lw in enumerate(lwsArray):
    Fs[i], Fq[i]= ksolverF(k_a, L_a, lw)

plt.figure(figsize=(8, 6), dpi=160)
plt.plot(lwsArray, Fs, 'k.', label = 'Right wall force calculated')
plt.plot(lwsArray, Fq, 'b-', label = 'Right wall force expected')
plt.ylabel('$F_{rw}$')
plt.xlabel('$L_{w}$')
plt.legend()
plt.title('Right wall force as a function of $L_w$')
plt.show()

# %% [markdown]
# a) It seems vaguely reasonable that the force on the rightmost wall decreases linearly as $L_w$ increases.
# b) The graph shows that the numerically derived force on the wall is equivalent to the force given by the law of equivalent springs.

# %% [markdown]
# Conclusion:
# Though going through the algebra was a bit troublesome at first due to a missed minus sign, translating the system of equation to a matrix equation was not too bad. Solving the equation using the matrix inverse was quite slick in all cases where the $\hat{K}$ was well-conditioned. Additionally, it was nice to verify the law of equivalent springs - or should I say to verify out numerical model against that law. I took a physics test in undergrad where I needed to derive the law of equivalent springs for a problem. Now I didn't manage to do that during hte time pressure of the test, but the form of the law has stuck with me ever since. It's like adding resistors (or inductors) in parallel or capacitors in series.
